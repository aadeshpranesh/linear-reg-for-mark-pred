# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
link="https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
ds=pd.read_csv(link)
print("link loaded")
ds.head(4)
# Out:
# link loaded
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75

# %%
#plotting of hours vs scores
ds.plot(x='Hours', y='Scores', style='o')
#ds.plot(x='Hours', y='Scores', style='o')
plt.title('graph')
plt.xlabel('studied hrs')
plt.ylabel('marks scored')
plt.show()

# %%
x=ds[['Hours']].values
y=ds[['Scores']].values
x,y
# Out:
# (array([[2.5],
#         [5.1],
#         [3.2],
#         [8.5],
#         [3.5],
#         [1.5],
#         [9.2],
#         [5.5],
#         [8.3],
#         [2.7],
#         [7.7],
#         [5.9],
#         [4.5],
#         [3.3],
#         [1.1],
#         [8.9],
#         [2.5],
#         [1.9],
#         [6.1],
#         [7.4],
#         [2.7],
#         [4.8],
#         [3.8],
#         [6.9],
#         [7.8]]),
#  array([[21],
#         [47],
#         [27],
#         [75],
#         [30],
#         [20],
#         [88],
#         [60],
#         [81],
#         [25],
#         [85],
#         [62],
#         [41],
#         [42],
#         [17],
#         [95],
#         [30],
#         [24],
#         [67],
#         [69],
#         [30],
#         [54],
#         [35],
#         [76],
#         [86]], dtype=int64))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)
y_train
# Out:
# array([[35],
#        [24],
#        [86],
#        [76],
#        [17],
#        [47],
#        [85],
#        [42],
#        [81],
#        [88],
#        [67],
#        [30],
#        [25],
#        [60],
#        [30],
#        [75],
#        [21],
#        [54],
#        [95],
#        [41]], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(x_train,y_train)
print("training complete")
# Out:
# training complete

# %%
#plotting lin reg
line= reg.coef_*x+reg.intercept_
plt.title('comparison')
plt.scatter(x,y)
plt.plot(x,line, color='red')
plt.show()

# %%
#predicting scores
print(x_test)
y_pred=reg.predict(x_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
print({"Actual": y_test, 'Predicted': y_pred})
# Out:
# {'Actual': array([[20],
#        [27],
#        [69],
#        [30],
#        [62]], dtype=int64), 'Predicted': array([[16.88414476],
#        [33.73226078],
#        [75.357018  ],
#        [26.79480124],
#        [60.49103328]])}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-3a45c71330cf> in <module>
# ----> 1 core_pred=np.array[7.45]
#       2 core_pred=core_pred.reshape(-1,1)
#       3 predict=regressor.predict(core_pred)
#       4 print("no of hrs".format(7.45))
#       5 print("pred score".format(predict[0]))
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
from sklearn import metrics
print("mean abs error",metrics.mean_absolute_error(y_test,y_pred))
# Out:
# mean abs error 4.183859899002975
